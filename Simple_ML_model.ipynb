# %%
from sklearn.linear_model import LinearRegression as lr
import pandas as pd
df=pd.read_csv("C:/Users/Benji/Desktop/Empty Folder/elect80.csv")
# Out:
#                FIPS         long          lat   pc_turnout   pc_college  \
# count   3107.000000  3107.000000  3107.000000  3107.000000  3107.000000
# mean   30712.852591   -91.638847    38.281092     0.572593     0.490358
# std    14982.781877    11.475691     4.838502     0.108013     0.101735
# min     1001.000000  -124.229900    25.117067     0.047026     0.208681
# 25%    19050.000000   -98.025277    34.687437     0.496615     0.408039
# 50%    29217.000000   -90.171689    38.327049     0.567892     0.504557
# 75%    46014.000000   -83.369519    41.691116     0.642946     0.566470
# max    56045.000000   -67.609990    48.833747     1.105263     0.846647
#
#        pc_homeownership    pc_income
# count       3107.000000  3107.000000
# mean           0.364645     8.552081
# std            0.044410     1.648232
# min            0.029579     4.322441
# 25%            0.343214     7.415863
# 50%            0.373433     8.394631
# 75%            0.395074     9.514892
# max            0.456749    24.962025

# %%
cols=list(df.columns)
cols.remove("FIPS")
cols.remove("pc_income")
predictor = lr()
f=predictor.fit(X=df[cols], y=df["pc_income"])
f.predict(df[cols])[1]
# Out:
# 9.209011590352643
